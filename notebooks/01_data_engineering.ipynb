# %% [markdown]
# # 01 - Data Engineering and Validation
# This notebook uses project code from `src/` to download real market data, engineer features, and validate quality.

# %%
from mlforecast_realworld.ml.pipeline import ForecastPipeline
pipeline = ForecastPipeline()

# %%
training_df = pipeline.prepare_training_data(download=True)
training_df.head()
# Out:
#   unique_id         ds     open     high      low    close     volume  \
# 0   AAPL.US 2015-01-02  24.6921  24.7037  23.8002  24.2374  239959065
# 1   AAPL.US 2015-01-05  24.0036  24.0802  23.3700  23.5555  289848502
# 2   AAPL.US 2015-01-06  23.6461  23.8160  23.1942  23.5575  296598610
# 3   AAPL.US 2015-01-07  23.7688  23.9820  23.6510  23.8917  180725843
# 4   AAPL.US 2015-01-08  24.2155  24.8669  24.0929  24.8079  267640572
#
#          y      sector asset_class  sector_code  asset_class_code  \
# 0  24.2374  Technology      equity            3                 1
# 1  23.5555  Technology      equity            3                 1
# 2  23.5575  Technology      equity            3                 1
# 3  23.8917  Technology      equity            3                 1
# 4  24.8079  Technology      equity            3                 1
#
#    sample_weight  is_weekend  is_month_start  is_month_end  week_of_year  \
# 0       0.332211           0               0             0             1
# 1       0.401280           0               0             0             2
# 2       0.410625           0               0             0             2
# 3       0.250205           0               0             0             2
# 4       0.370534           0               0             0             2
#
#    month_sin  month_cos
# 0        0.5   0.866025
# 1        0.5   0.866025
# 2        0.5   0.866025
# 3        0.5   0.866025
# 4        0.5   0.866025

# %%
report = pipeline.data_engineer.quality_report(training_df)
report
# Out:
# DataQualityReport(rows=13980, series=5, start=Timestamp('2015-01-02 00:00:00'), end=Timestamp('2026-02-13 00:00:00'), missing_rate=0.0)

# %%
static_df = pipeline.data_engineer.build_static_features(training_df)
static_df
# Out:
#   unique_id                  sector asset_class  sector_code  asset_class_code
# 0   AAPL.US              Technology      equity            3                 1
# 1   AMZN.US  Consumer Discretionary      equity            2                 1
# 2   GOOG.US  Communication Services      equity            1                 1
# 3   META.US  Communication Services      equity            1                 1
# 4   MSFT.US              Technology      equity            3                 1

# %%
future_x = pipeline.data_engineer.build_future_exogenous(
    ids=sorted(training_df['unique_id'].unique().tolist()),
    last_timestamp=training_df['ds'].max(),
    horizon=7,
    freq=pipeline.settings.forecast.freq,
)
future_x.head()
# Out:
#   unique_id         ds  is_weekend  is_month_start  is_month_end  \
# 0   AAPL.US 2026-02-16           0               0             0
# 1   AAPL.US 2026-02-17           0               0             0
# 2   AAPL.US 2026-02-18           0               0             0
# 3   AAPL.US 2026-02-19           0               0             0
# 4   AAPL.US 2026-02-20           0               0             0
#
#    week_of_year  month_sin  month_cos
# 0             8   0.866025        0.5
# 1             8   0.866025        0.5
# 2             8   0.866025        0.5
# 3             8   0.866025        0.5
# 4             8   0.866025        0.5
